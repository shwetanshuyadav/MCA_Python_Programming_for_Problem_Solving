# %%
num = int(input("Enter a number: "))
print("Entered value: {}".format(num))
print("Binary:      {}".format(bin(num)[2:]))
print("Octal:       {}".format(oct(num)[2:]))
print("Hexadecimal: {}".format(hex(num)[2:].upper()))
# Out:
# Entered value: 25
# Binary:      11001
# Octal:       31
# Hexadecimal: 19
