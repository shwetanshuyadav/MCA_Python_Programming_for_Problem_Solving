# %%
items = ["apple", "banana", "apple", "orange", "banana"]

unique_sorted_items = sorted(set(items))

print(f"Unique & Sorted Items: {unique_sorted_items}")
# Out:
# Unique & Sorted Items: ['apple', 'banana', 'orange']
