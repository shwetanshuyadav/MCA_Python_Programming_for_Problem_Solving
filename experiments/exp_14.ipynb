# %%
from shapes import circle_area, circle_perimeter
from shapes import rectangle_area, rectangle_perimeter

print("Circle Area:", circle_area(5))
print("Circle Perimeter:", circle_perimeter(5))

print("Rectangle Area:", rectangle_area(4, 6))
print("Rectangle Perimeter:", rectangle_perimeter(4, 6))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from shapes import circle_area, circle_perimeter
#       2 from shapes import rectangle_area, rectangle_perimeter
#       4 print("Circle Area:", circle_area(5))
#
# ImportError: cannot import name 'circle_area' from 'shapes' (c:\Users\Keerti\OneDrive\Desktop\MCA 1sem\Ansh\Python\Pratical record\shapes\__init__.py)
